# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_csv(r"C:\Users\ABC\Downloads\data - data.csv")
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.head(10)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
# 5   6    2008      Jaipur  2008-04-21        Kings XI Punjab
# 6   7    2008   Hyderabad  2008-04-22        Deccan Chargers
# 7   8    2008     Chennai  2008-04-23    Chennai Super Kings
# 8   9    2008   Hyderabad  2008-04-24        Deccan Chargers
# 9  10    2008  Chandigarh  2008-04-25        Kings XI Punjab
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# ...

# %%
data.tail(10)
# Out:
#       id  season           city        date                  team1  \
# 567  568    2016         Kanpur  2016-05-19  Kolkata Knight Riders
# 568  569    2016         Raipur  2016-05-20    Sunrisers Hyderabad
# 569  570    2016  Visakhapatnam  2016-05-21        Kings XI Punjab
# 570  571    2016         Kanpur  2016-05-21         Mumbai Indians
# 571  572    2016        Kolkata  2016-05-22  Kolkata Knight Riders
# 572  573    2016         Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016      Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016          Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016          Delhi  2016-05-27          Gujarat Lions
# 576  577    2016      Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 567                Gujarat Lions                Gujarat Lions         field
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.shape
# Out:
# (577, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
data=data.drop('umpire3',axis=1,errors='ignore')
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data=data.dropna()
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
data=data.drop_duplicates()
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
Q1=data["win_by_runs"].quantile(0.25)
Q3=data["win_by_runs"].quantile(0.75)
IQR= Q3-Q1
print(IQR)
lowerlimit=Q1-1.5*IQR
upperlimit=Q3+1.5*IQR
print(lowerlimit,upperlimit)
data[((data["win_by_runs"])<lowerlimit)|((data["win_by_runs"])>upperlimit)]
# Out:
# 21.0
# -31.5 52.5
#       id  season            city        date                        team1  \
# 0      1    2008       Bangalore  2008-04-18        Kolkata Knight Riders
# 9     10    2008      Chandigarh  2008-04-25              Kings XI Punjab
# 41    42    2008          Jaipur  2008-05-17             Rajasthan Royals
# 55    56    2008          Mumbai  2008-05-30             Rajasthan Royals
# 59    60    2009       Cape Town  2009-04-18  Royal Challengers Bangalore
# 62    63    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 72    73    2009  Port Elizabeth  2009-04-27               Mumbai Indians
# 84    85    2009     East London  2009-05-04          Chennai Super Kings
# 85    86    2009          Durban  2009-05-05             Rajasthan Royals
# 95    96    2009       Kimberley  2009-05-11              Deccan Chargers
# 122  123    2010         Kolkata  2010-03-16          Chennai Super Kings
# ...

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data.isnull(), cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data['toss_decision'].value_counts()["bat"]
# Out:
# 258

# %%
data["toss_decision"].value_counts()["field"]
# Out:
# 309

# %%
data["result"].value_counts()
# Out:
# result
# normal    561
# tie         6
# Name: count, dtype: int64

# %%
data['toss_decision'].replace({"bat":1 , "field":0},inplace=True)
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner  toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore              0
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
p3=sns.countplot(data["win_by_wickets"])
p4 = sns.countplot(data["win_by_runs"])
plt.show()

# %%
sns.histplot(data['win_by_runs'],kde=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,4)
plt.pie(data["toss_winner"].value_counts(), autopct='%.2f')
plt.title("toss_winner")

plt.subplot(2,2,3)
plt.pie(data["winner"].value_counts(),autopct='%.2f')
plt.title("winner")

plt.subplot(2,2,2)
plt.pie(data["season"].value_counts(),autopct='%.2f')
plt.title("season")

plt.show()

# %%
data["winner"].describe()
# Out:
# count                567
# unique                13
# top       Mumbai Indians
# freq                  80
# Name: winner, dtype: object

# %%
data["win_by_runs"].skew()
# Out:
# 2.4124542918648957

# %%
plt.hist(data["win_by_runs"])
plt.show()

# %%
sns.histplot(data["win_by_runs"],kde=True)
plt.show()

# %%
sns.boxplot(data["win_by_runs"])
plt.show()

# %%
sns.barplot(x=data[''],y=data['diet'])
